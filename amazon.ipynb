# %%
import pandas as pd

# %%
df = pd.read_sql('amazon_orders',con = 'sqlite:///app_base.db').dropna()
df
# Out:
#      index                 order_date              order_id  \
# 0        0  2025-05-04 12:13:57+00:00   402-8011422-3979556
# 1        1  2025-05-04 06:13:55+00:00   406-1540229-6779502
# 2        2  2025-05-02 21:12:58+00:00   404-3781492-0928354
# 3        3  2025-05-02 00:35:47+00:00   405-7320250-1113139
# 4        4  2025-05-01 20:51:01+00:00   407-1772662-1363537
# ..     ...                        ...                   ...
# 495    495  2024-03-17 21:36:10+00:00                  None
# 496    496  2024-03-17 14:50:04+00:00                  None
# 497    497  2024-03-17 10:31:49+00:00                  None
# 498    498  2024-03-17 06:09:31+00:00                  None
# 499    499  2024-03-16 23:04:52+00:00                  None
#
#           shipping_type cod_prepaid cod_amount max_shipping_date  \
# 0     Standard Shipping        0.00     215.00        06/05/2025
# 1     Standard Shipping        None       None        06/05/2025
# ...

# %%
df['order_id']
# Out:
# 0       402-8011422-3979556
# 1       406-1540229-6779502
# 2       404-3781492-0928354
# 3       405-7320250-1113139
# 4       407-1772662-1363537
#                ...
# 495                    None
# 496                    None
# 497                    None
# 498                    None
# 499                    None
# Name: order_id, Length: 500, dtype: object
